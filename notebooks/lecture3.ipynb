# %% [markdown]
# # 3일차 · 시맨틱 웹 표준과 RDF 데이터 모델
#
# **모듈:** 시맨틱 웹 표준과 RDF 데이터 모델
# **교육시간:** 8hr
#
# ---
#
# **연결 학습:** Graph RAG(2일차) → RDF/OWL 기반 지식 표현(3·4일차)

# %% [markdown]
# ## 목차
#
# 1. [강의 개요](#강의-개요)
# 2. [1. 시맨틱 웹과 지식 표현 기초](#1-시맨틱-웹과-지식-표현-기초)
# 3. [2. RDF 트리플 모델링](#2-rdf-트리플-모델링)
# 4. [3. RDF 형식 및 변환 실습](#3-rdf-형식-및-변환-실습)
# 5. [정리 & 참고](#정리--참고)

# %% [markdown]
# ## 강의 개요
#
# - **오늘 다룰 내용:** 시맨틱 웹 탄생 배경, RDF 트리플(SPO), RDF/XML·Turtle 등 형식 및 변환
# - **학습 목표:**
#   - 시맨틱 웹의 탄생 배경과 웹 데이터의 의미론적 연결 원리 이해
#   - RDF 트리플: 주어-서술어-목적어(Subject-Predicate-Object) 모델링
#   - RDF/XML, Turtle 등 다양한 형식의 데이터 표현 및 변환 실습

# %% [markdown]
# ## 1. 시맨틱 웹과 지식 표현 기초

# %% [markdown]
# ### 1.1 시맨틱 웹의 탄생 배경

# %% [markdown]
# ### 1.2 웹 데이터의 의미론적 연결 원리

# %% [markdown]
# ## 2. RDF 트리플 모델링

# %% [markdown]
# ### 2.1 Subject–Predicate–Object 구조

# %% [markdown]
# ### 2.2 그래프 관점에서의 RDF

# %% [markdown]
# ## 3. RDF 형식 및 변환 실습

# %% [markdown]
# ### 3.1 RDF/XML, Turtle 등 형식

# %% [markdown]
# ### 3.2 변환 실습

# %% [markdown]
# ### RDF 실습 코드

# %%
# 3일차 실습: RDF 생성, Turtle/XML, 변환

# %% [markdown]
# ## 정리 & 참고
#
# - **오늘 요약:**
#   -
# - **질문 / 나중에 확인할 것:**
#   -
# - **참고 자료:**
#   -
