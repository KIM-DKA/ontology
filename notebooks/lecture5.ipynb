# %% [markdown]
# # 5일차 · 최종 프로젝트
#
# **모듈:** 최종 프로젝트
# **교육시간:** 8hr
#
# ---
#
# **목표:** 제조 분야 데이터를 바탕으로 **지식 그래프 구축** 및 **RAG 시스템** 완성
# 1~4일차 학습 내용(RAG, Graph RAG, RDF, OWL/SPARQL 등)을 통합 적용.

# %% [markdown]
# ## 목차
#
# 1. [프로젝트 개요](#프로젝트-개요)
# 2. [데이터 및 도메인 정의](#데이터-및-도메인-정의)
# 3. [지식 그래프 구축](#지식-그래프-구축)
# 4. [RAG/질의응답 시스템 연동](#rag질의응답-시스템-연동)
# 5. [결과 정리 및 제출](#결과-정리-및-제출)

# %% [markdown]
# ## 프로젝트 개요
#
# - **주제:** 제조 데이터 프로젝트
# - **범위:** 제조 분야 데이터 수집/정의, 지식 그래프 구축, RAG 시스템 완성
# - **체크리스트:** 도메인·데이터 소스 정의, 지식 그래프 스키마/온톨로지 설계, 데이터 적재 및 검증, RAG 파이프라인 구현, 질의응답 테스트 및 정리

# %% [markdown]
# ## 데이터 및 도메인 정의

# %% [markdown]
# ### 사용 데이터 소스
#
# (제조 설비, 공정, 자재, 매뉴얼, 규정 등)

# %% [markdown]
# ### 도메인 온톨로지/스키마 요약

# %% [markdown]
# ## 지식 그래프 구축

# %% [markdown]
# ### 스키마 설계

# %% [markdown]
# ### 데이터 적재 및 검증

# %% [markdown]
# ### 지식 그래프 구축 실습 코드

# %%
# 지식 그래프 구축: 스키마, 적재, SPARQL/Cypher 등

# %% [markdown]
# ## RAG/질의응답 시스템 연동

# %% [markdown]
# ### 파이프라인 구성
#
# (Retriever, Vector DB, Graph RAG, LLM 등)

# %% [markdown]
# ### 질의 예시 및 응답 검증

# %% [markdown]
# ### RAG 파이프라인 실습 코드

# %%
# RAG 파이프라인, LangChain 등 연동 및 QA 테스트

# %% [markdown]
# ## 결과 정리 및 제출
#
# - **구현 요약:**
#   -
# - **한계점 / 개선 방향:**
#   -
# - **참고 자료:**
#   -
