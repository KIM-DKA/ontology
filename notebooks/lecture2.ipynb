# %% [markdown]
# # 2일차 · Graph RAG
#
# **모듈:** Graph RAG
# **교육시간:** 8hr
#
# ---
#
# **연결 학습:** 1일차 RAG → 2일차 그래프 기반 지식 표현 및 추출

# %% [markdown]
# ## 목차
#
# 1. [강의 개요](#강의-개요)
# 2. [1. Graph RAG 이해](#1-graph-rag-이해)
# 3. [2. Cypher 기초](#2-cypher-기초)
# 4. [3. LLM을 활용한 지식 추출](#3-llm을-활용한-지식-추출)
# 5. [정리 & 참고](#정리--참고)

# %% [markdown]
# ## 강의 개요
#
# - **오늘 다룰 내용:** LPG 모델, RDB→그래프 스키마 전환, Cypher, Entity/Relation 추출 → Neo4j
# - **학습 목표:**
#   - LPG(노드·관계·속성) 모델링 이해
#   - RDB에서 그래프 모델로의 스키마 설계 전환
#   - Cypher로 그래프 데이터 조작
#   - 비정형 텍스트에서 Entity·Relation 추출 후 Neo4j 자동 적재

# %% [markdown]
# ## 1. Graph RAG 이해

# %% [markdown]
# ### 1.1 LPG(Labeled Property Graph)
#
# - **노드(Node), 관계(Relationship), 속성(Property)** 모델링

# %% [markdown]
# ### 1.2 RDB → 그래프 모델 스키마 전환 전략

# %% [markdown]
# ## 2. Cypher 기초

# %% [markdown]
# ### 2.1 그래프 데이터 조작을 위한 Cypher 문법

# %% [markdown]
# ### 2.2 실습 예제

# %% [markdown]
# ### Cypher / Neo4j 실습 코드

# %%
# 2일차 실습: Cypher, Neo4j 연결 등

# %% [markdown]
# ## 3. LLM을 활용한 지식 추출

# %% [markdown]
# ### 3.1 Knowledge Extraction 개요
#
# - 비정형 텍스트 → **Entity**, **Relation** 추출

# %% [markdown]
# ### 3.2 Neo4j 자동 적재 파이프라인

# %%
# 지식 추출 → Neo4j 적재 실습

# %% [markdown]
# ## 정리 & 참고
#
# - **오늘 요약:**
#   -
# - **질문 / 나중에 확인할 것:**
#   -
# - **참고 자료:**
#   -
